# %% [markdown]
# <a href="https://colab.research.google.com/github/rohanbhavsar64/code1/blob/main/ABC_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('orders_and_shipments.csv')

# %%
df
# Out:
#        Order ID    Order Item ID    Order YearMonth    Order Year   \
# 0           3535             8793             201502          2015
# 1           4133            10320             201503          2015
# 2           7396            18517             201504          2015
# 3          11026            27608             201506          2015
# 4          11026            27609             201506          2015
# ...          ...              ...                ...           ...
# 30866      73246           176561             201712          2017
# 30867       7908            19762             201504          2015
# 30868      29326            73368             201603          2016
# 30869      63308           158284             201707          2017
# 30870      67951           169874             201709          2017
#
#         Order Month    Order Day  Order Time  Order Quantity  \
# 0                  2           21      14:07               1
# 1                  3            2      07:37               1
# 2                  4           18      22:47               1
# 3                  6           10      22:32               1
# 4                  6           10      22:32               1
# ...              ...          ...        ...             ...
# 30866             12            5      04:59               1
# 30867              4           26      10:10               1
# 30868              3            4      01:51               1
# 30869              7           13      03:15               1
# 30870              9           18      21:54               1
#
#       Product Department    Product Category  ... Customer Country  \
# 0               Fan Shop             Fishing  ...           Mexico
# 1               Fan Shop             Fishing  ...           Brazil
# 2               Fan Shop             Fishing  ...           Mexico
# 3               Fan Shop             Fishing  ...          Denmark
# 4               Fan Shop             Fishing  ...          Denmark
# ...                  ...                 ...  ...              ...
# 30866           Fan Shop                Toys  ...        Australia
# 30867           Fan Shop  Hunting & Shooting  ...         Paraguay
# 30868           Fan Shop  Hunting & Shooting  ...            India
# 30869           Fan Shop  Hunting & Shooting  ...          Germany
# 30870           Fan Shop        Water Sports  ...            Italy
#
#        Warehouse Country Shipment Year Shipment Month Shipment Day  \
# 0            Puerto Rico          2015              2           27
# 1            Puerto Rico          2015              3            6
# 2            Puerto Rico          2015              4           20
# 3            Puerto Rico          2015              6           12
# 4            Puerto Rico          2015              6           12
# ...                  ...           ...            ...          ...
# 30866        Puerto Rico          2017             12           11
# 30867        Puerto Rico          2015              4           30
# 30868        Puerto Rico          2016              3            6
# 30869        Puerto Rico          2017              7           17
# 30870        Puerto Rico          2017              9           20
#
#         Shipment Mode   Shipment Days - Scheduled    Gross Sales   \
# 0      Standard Class                            4            400
# 1      Standard Class                            4            400
# 2      Standard Class                            4            400
# 3      Standard Class                            4            400
# 4      Standard Class                            4            400
# ...               ...                          ...            ...
# 30866  Standard Class                            4             12
# 30867  Standard Class                            4             30
# 30868    Second Class                            2             30
# 30869    Second Class                            2            150
# 30870     First Class                            1            350
#
#         Discount %   Profit
# 0              0.25      200
# 1              0.09      200
# 2              0.06      200
# 3              0.15      200
# 4              0.13      200
# ...             ...      ...
# 30866          0.06        6
# 30867          0.12       68
# 30868          0.09       68
# 30869          0.02       60
# 30870           -        172
#
# [30871 rows x 24 columns]

# %%
df['Unit Price'] = df[' Gross Sales '] /df['Order Quantity']
df
# Out:
#        Order ID    Order Item ID    Order YearMonth    Order Year   \
# 0           3535             8793             201502          2015
# 1           4133            10320             201503          2015
# 2           7396            18517             201504          2015
# 3          11026            27608             201506          2015
# 4          11026            27609             201506          2015
# ...          ...              ...                ...           ...
# 30866      73246           176561             201712          2017
# 30867       7908            19762             201504          2015
# 30868      29326            73368             201603          2016
# 30869      63308           158284             201707          2017
# 30870      67951           169874             201709          2017
#
#         Order Month    Order Day  Order Time  Order Quantity  \
# 0                  2           21      14:07               1
# 1                  3            2      07:37               1
# 2                  4           18      22:47               1
# 3                  6           10      22:32               1
# 4                  6           10      22:32               1
# ...              ...          ...        ...             ...
# 30866             12            5      04:59               1
# 30867              4           26      10:10               1
# 30868              3            4      01:51               1
# 30869              7           13      03:15               1
# 30870              9           18      21:54               1
#
#       Product Department    Product Category  ... Warehouse Country  \
# 0               Fan Shop             Fishing  ...       Puerto Rico
# 1               Fan Shop             Fishing  ...       Puerto Rico
# 2               Fan Shop             Fishing  ...       Puerto Rico
# 3               Fan Shop             Fishing  ...       Puerto Rico
# 4               Fan Shop             Fishing  ...       Puerto Rico
# ...                  ...                 ...  ...               ...
# 30866           Fan Shop                Toys  ...       Puerto Rico
# 30867           Fan Shop  Hunting & Shooting  ...       Puerto Rico
# 30868           Fan Shop  Hunting & Shooting  ...       Puerto Rico
# 30869           Fan Shop  Hunting & Shooting  ...       Puerto Rico
# 30870           Fan Shop        Water Sports  ...       Puerto Rico
#
#        Shipment Year Shipment Month Shipment Day   Shipment Mode  \
# 0               2015              2           27  Standard Class
# 1               2015              3            6  Standard Class
# 2               2015              4           20  Standard Class
# 3               2015              6           12  Standard Class
# 4               2015              6           12  Standard Class
# ...              ...            ...          ...             ...
# 30866           2017             12           11  Standard Class
# 30867           2015              4           30  Standard Class
# 30868           2016              3            6    Second Class
# 30869           2017              7           17    Second Class
# 30870           2017              9           20     First Class
#
#        Shipment Days - Scheduled    Gross Sales    Discount %    Profit   \
# 0                               4            400          0.25       200
# 1                               4            400          0.09       200
# 2                               4            400          0.06       200
# 3                               4            400          0.15       200
# 4                               4            400          0.13       200
# ...                           ...            ...           ...       ...
# 30866                           4             12          0.06         6
# 30867                           4             30          0.12        68
# 30868                           2             30          0.09        68
# 30869                           2            150          0.02        60
# 30870                           1            350           -         172
#
#       Unit Price
# 0          400.0
# 1          400.0
# 2          400.0
# 3          400.0
# 4          400.0
# ...          ...
# 30866       12.0
# 30867       30.0
# 30868       30.0
# 30869      150.0
# 30870      350.0
#
# [30871 rows x 25 columns]

# %%
df.columns
# Out:
# Index(['Order ID ', ' Order Item ID ', ' Order YearMonth ', ' Order Year ',
#        ' Order Month ', ' Order Day ', 'Order Time', 'Order Quantity',
#        'Product Department', 'Product Category', 'Product Name',
#        ' Customer ID ', 'Customer Market', 'Customer Region',
#        'Customer Country', 'Warehouse Country', 'Shipment Year',
#        'Shipment Month', 'Shipment Day', 'Shipment Mode',
#        ' Shipment Days - Scheduled ', ' Gross Sales ', ' Discount % ',
#        ' Profit '],
#       dtype='object')

# %%
df['TotalValue'] = df['Order Quantity'] * df['Unit Price']
df = df.sort_values(by='TotalValue', ascending=False)
df['CumulativeValue'] = df['TotalValue'].cumsum()
total_value = df['TotalValue'].sum()
df['CumulativePercentage'] = (df['CumulativeValue'] / total_value) * 100
def classify_abc(row):
    if row['CumulativePercentage'] < 70:
        return 'A'
    elif (row['CumulativePercentage'] >70) and (row['CumulativePercentage'] < 90):
        return 'B'
    else:
        return 'C'

df['Category'] = df.apply(classify_abc, axis=1)
print(df[['Category', 'TotalValue', 'CumulativePercentage']])
# Out:
#       Category  TotalValue  CumulativePercentage
# 15451        A       533.0              0.008623
# 15495        A       533.0              0.017245
# 28847        A       533.0              0.025868
# 28846        A       533.0              0.034490
# 15441        A       533.0              0.043113
# ...        ...         ...                   ...
# 2079         C        10.0             99.999353
# 21237        C        10.0             99.999515
# 24822        C        10.0             99.999676
# 14805        C        10.0             99.999838
# 24827        C        10.0            100.000000
#
# [30871 rows x 3 columns]

# %%
df
# Out:
#        Order ID    Order Item ID    Order YearMonth    Order Year   \
# 15451      71875           175190             201711          2017
# 15495      71853           175168             201711          2017
# 28847      71838           175153             201711          2017
# 28846      71803           175118             201711          2017
# 15441      71871           175186             201602          2016
# ...          ...              ...                ...           ...
# 2079       27201            68147             201706          2017
# 21237      43925           109723             201610          2016
# 24822      41098           102603             201704          2017
# 14805      33648            83980             201606          2016
# 24827       7361            18434             201603          2016
#
#         Order Month    Order Day  Order Time  Order Quantity  \
# 15451             11           22      20:35               1
# 15495             11           20      03:46               1
# 28847             11           14      09:23               1
# 28846             11           12      20:57               1
# 15441              2            6      03:28               1
# ...              ...          ...        ...             ...
# 2079               6           12      15:23               1
# 21237             10            3      04:32               1
# 24822              4           23      09:09               1
# 14805              6           20      13:15               1
# 24827              3           18      20:03               1
#
#       Product Department Product Category  ...   Shipment Mode  \
# 15451           Outdoors           Garden  ...  Standard Class
# 15495           Outdoors           Garden  ...  Standard Class
# 28847           Outdoors           Garden  ...  Standard Class
# 28846           Outdoors           Garden  ...  Standard Class
# 15441           Outdoors           Garden  ...     First Class
# ...                  ...              ...  ...             ...
# 2079            Outdoors      Golf Gloves  ...  Standard Class
# 21237           Outdoors      Golf Gloves  ...  Standard Class
# 24822           Outdoors      Golf Gloves  ...    Second Class
# 14805           Outdoors      Golf Gloves  ...     First Class
# 24827           Outdoors      Golf Gloves  ...    Second Class
#
#         Shipment Days - Scheduled   Gross Sales   Discount %   Profit   \
# 15451                            4           533         0.03      258
# 15495                            4           533         0.07      258
# 28847                            4           533         0.04      258
# 28846                            4           533         0.03      258
# 15441                            1           533         0.07      258
# ...                            ...           ...          ...      ...
# 2079                             4            10         0.16       16
# 21237                            4            10         0.16       16
# 24822                            2            10          -         16
# 14805                            1            10         0.04       16
# 24827                            2            10         0.17       16
#
#       Unit Price  TotalValue  CumulativeValue  CumulativePercentage Category
# 15451      533.0       533.0            533.0              0.008623        A
# 15495      533.0       533.0           1066.0              0.017245        A
# 28847      533.0       533.0           1599.0              0.025868        A
# 28846      533.0       533.0           2132.0              0.034490        A
# 15441      533.0       533.0           2665.0              0.043113        A
# ...          ...         ...              ...                   ...      ...
# 2079        10.0        10.0        6181436.0             99.999353        C
# 21237       10.0        10.0        6181446.0             99.999515        C
# 24822       10.0        10.0        6181456.0             99.999676        C
# 14805       10.0        10.0        6181466.0             99.999838        C
# 24827       10.0        10.0        6181476.0            100.000000        C
#
# [30871 rows x 29 columns]

# %%
df[df['Category']=='A']['Product Category'].unique()
# Out:
# array(['Garden', 'Cardio Equipment', "Men's Golf Clubs",
#        'As Seen on  TV!', 'Golf Shoes', "Women's Golf Clubs",
#        'Hunting & Shooting', 'Boxing & MMA', 'Crafts', 'Cameras',
#        "Kids' Golf Clubs", 'Fishing', 'Golf Gloves', 'Lacrosse',
#        'Strength Training', 'Soccer', "Children's Clothing",
#        "Girls' Apparel", 'Water Sports', 'Hockey', 'Sporting Goods',
#        'Camping & Hiking', 'Cleats', 'Baseball & Softball', 'Basketball',
#        'Health and Beauty', 'Music', 'Electronics',
#        'Consumer Electronics', "Women's Apparel", 'Indoor/Outdoor Games',
#        'Trade-In', 'Tennis & Racquet', "Women's Clothing",
#        "Men's Clothing", 'Shop By Sport'], dtype=object)

# %%
df[df['Category']=='B']['Product Category'].unique()
# Out:
# array(['Cardio Equipment', "Women's Golf Clubs", 'Lacrosse',
#        'Shop By Sport', 'Water Sports', "Kids' Golf Clubs",
#        "Girls' Apparel", 'Indoor/Outdoor Games', "Women's Apparel",
#        'Hunting & Shooting', 'Golf Shoes', 'Electronics', 'Boxing & MMA',
#        'Strength Training', 'Cleats', 'Baseball & Softball',
#        'Tennis & Racquet', 'Golf Gloves', 'Fitness Accessories',
#        'Golf Bags & Carts', 'DVDs', 'Soccer', "Men's Golf Clubs",
#        "Men's Footwear", 'Golf Apparel', 'Accessories', 'Hockey'],
#       dtype=object)

# %%
df[df['Category']=='C']['Product Category'].unique()
# Out:
# array(['Cleats', 'Shop By Sport', 'Cardio Equipment', 'Golf Gloves',
#        "Girls' Apparel", 'Baseball & Softball', 'Golf Apparel',
#        'Hunting & Shooting', 'Electronics', "Men's Golf Clubs",
#        "Kids' Golf Clubs", 'Trade-In', 'Boxing & MMA', 'Hockey',
#        'Golf Shoes', 'Fitness Accessories', "Women's Apparel",
#        'Indoor/Outdoor Games', 'Accessories', 'Lacrosse', 'Golf Balls',
#        'As Seen on  TV!', 'Tennis & Racquet', 'Pet Supplies',
#        "Women's Golf Clubs", 'Soccer', 'Baby', 'Video Games', 'Books',
#        'Toys', 'CDs'], dtype=object)

# %%
df[df['TotalValue']==1225]['Product Category'].unique()
# Out:
# array(['Cardio Equipment'], dtype=object)

# %%
df1=pd.read_csv('fulfillment.csv')

# %%
df1
# Out:
#                                       Product Name  \
# 0                 Perfect Fitness Perfect Rip Deck
# 1             Nike Men's Dri-FIT Victory Golf Polo
# 2                 O'Brien Men's Neoprene Life Vest
# 3                Nike Men's Free 5.0+ Running Shoe
# 4    Under Armour Girls' Toddler Spine Surge Runni
# ..                                             ...
# 113  Stiga Master Series ST3100 Competition Indoor
# 114                            SOLE E35 Elliptical
# 115         Bushnell Pro X7 Jolt Slope Rangefinder
# 116                            SOLE E25 Elliptical
# 117              Bowflex SelectTech 1090 Dumbbells
#
#       Warehouse Order Fulfillment (days)
# 0                                     8.3
# 1                                     6.6
# 2                                     5.5
# 3                                     9.4
# 4                                     6.3
# ..                                    ...
# 113                                   4.7
# 114                                   1.9
# 115                                   2.0
# 116                                   2.1
# 117                                   7.7
#
# [118 rows x 2 columns]

# %%
df2=pd.read_csv('inventory.csv')

# %%
df2
# Out:
#                                        Product Name   Year Month   \
# 0                  Perfect Fitness Perfect Rip Deck        201712
# 1              Nike Men's Dri-FIT Victory Golf Polo        201712
# 2                  O'Brien Men's Neoprene Life Vest        201712
# 3                 Nike Men's Free 5.0+ Running Shoe        201712
# 4     Under Armour Girls' Toddler Spine Surge Runni        201712
# ...                                             ...           ...
# 4195             TaylorMade 2017 Purelite Stand Bag        201501
# 4196                           Ogio Race Golf Shoes        201501
# 4197                        GolfBuddy VT3 GPS Watch        201501
# 4198            Titleist Small Wheeled Travel Cover        201501
# 4199                    Polar Loop Activity Tracker        201501
#
#        Warehouse Inventory   Inventory Cost Per Unit
# 0                         0                  0.69517
# 1                         2                  1.29291
# 2                         0                  0.56531
# 3                         1                  1.26321
# 4                         0                  1.47648
# ...                     ...                      ...
# 4195                      0                  1.44662
# 4196                      0                  0.10310
# 4197                      0                  1.77747
# 4198                      0                  0.15244
# 4199                      1                  0.88259
#
# [4200 rows x 4 columns]
